# %%
import pandas as pd
import re
import urllib.request
from bs4 import BeautifulSoup
import json
import time
import spacy

from __future__ import unicode_literals, print_function
import random
from pathlib import Path

import math
from collections import Counter

import datetime

import fuzzyset

# %%
def getArtistDetailsFromAZ(p_artist_name_bb):
    p_artist_group_az = ''
    p_artist_name_az = ''
    p_artist_url_az = ''
    p_accuracy = 0
    p_match_count = 0
    p_index_set = ''
    
    t_artist_name_bb = removeSingleCharStopWords(addSpaceAfterDot(p_artist_name_bb))
    
    for index, row in az_artist_data.iterrows():
        t_accuracy = 0
        t_compare_result = []
        
        t_artist_name_az = row['name_words']
        
        if len(t_artist_name_az) > 0:
            t_compare_result = getCosine(t_artist_name_az, t_artist_name_bb)
            t_accuracy = round(len(t_compare_result)/len(t_artist_name_bb), 2)
        else:
            t_accuracy = 0
        
        if t_accuracy > p_accuracy and t_accuracy != 0:
            p_match_count = 1
            p_accuracy = t_accuracy
            p_artist_group_az = row['artist_group']
            p_artist_name_az = row['artist_name']
            p_artist_url_az = row['artist_url']
            p_index_set = str(index + 1)
        elif t_accuracy == p_accuracy and t_accuracy != 0:
            p_match_count += 1
            p_artist_group_az = p_artist_group_az + '|' + row['artist_group']
            p_artist_name_az = p_artist_name_az + '|' + row['artist_name']
            p_artist_url_az = p_artist_url_az + '|' + row['artist_url']
            p_index_set = p_index_set + '|' + str(index + 1)
    
    return [p_artist_group_az, p_artist_name_az, p_artist_url_az, p_accuracy, p_index_set, p_match_count]

def generateAutoIDforDataFrame(df, df_column):
    df.insert(0, df_column, range(1, 1 + len(df)))
    return df

def compareSets(p_set_to_compare_with, p_set_to_compare):
    return pd.Index(p_set_to_compare_with).intersection(pd.Index(p_set_to_compare))

def removeSpecialCharacter(param):
    return re.sub('\W+', ' ', param)

def removeSingleCharacterWord(param):
    return list(filter(lambda x: len(x) > 1, param))

def addSpaceAfterDot(param):
    return re.sub('\.+', '. ', param).replace('  ', ' ')

def removeSingleCharStopWords(param):
    doc = nlp(param)
    
    wordset = []
    
    for token in doc:
        if len(token.text) > 1 and not token.is_stop:
            wordset.append(token.lower_)
    return wordset

def removeDuplicate(param):
    result = []
    for w in param:
        if w not in result:
            result.append(w)
    return result

def intersection(list_to_compare=[], list_set_to_compare_with=[]):
    # Returns a list (same lenght as list_set_to_compare_with) having multiple matched elements
    result_list = [list(filter(lambda x: x in list_to_compare, sublist)) for sublist in list_set_to_compare_with]
    
    # Get the max length of sub-list from the return list
    result_list_max = max(result_list, key=len)
    
    # Get all the index list based on result_list_max
    index_list = []
    if len(result_list_max) != 0:
        index_list = [index for index, row in enumerate(result_list) if row == result_list_max]
    
    return index_list, len(result_list_max)

def getCosine(vec1, vec2):
    common = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in common])

    sum1 = sum([vec1[x]**2 for x in vec1.keys()]) 
    sum2 = sum([vec2[x]**2 for x in vec2.keys()]) 
    denominator = math.sqrt(sum1) * math.sqrt(sum2)
   
    if not denominator:
        return 0.0 
    else:
        return float(numerator) / denominator

print('Loaded Functions!')
# Out:
# Loaded Functions!

# %%
az_artist_data = pd.read_csv('data/az_artist_data.csv')
bb_artist_data = pd.read_csv('data/bb_artist_data.csv')

az_artist_data = generateAutoIDforDataFrame(az_artist_data, 'artist_id_az')

# %%
domain_az = 'https://www.azlyrics.com/'
domain_bb = 'https://www.billboard.com/'

artist_data = bb_artist_data\
    .loc[bb_artist_data['artist_category'].isin(['Artist'])]\
    .drop(columns=['artist_category'])\
    .rename(index=str, columns={
        'artist_id': 'artist_id_bb',
        'artist_url': 'artist_url_bb', 
        'artist_name': 'artist_name_bb'})\
    
artist_data = pd.merge(artist_data, az_artist_data, how='left', 
        left_on=['artist_name_bb'], right_on=['artist_name'])\
    .rename(index=str, columns={
        'artist_group_x': 'artist_group_bb',
        'artist_group_y': 'artist_group_az', 
        'artist_url': 'artist_url_az',
        'artist_name': 'artist_name_az'})

artist_data.head()
# Out:
#   artist_group_bb  artist_id_bb              artist_name_bb  \
# 0               A      275128.0  A B C & D of Boogie Woogie
# 1               A      275133.0              A Band of Bees
# 2               A     6824928.0                 A Lu A Zhuo
# 3               A     7665908.0                       A Niu
# 4               A     1481643.0                      A Plus
#
#                         artist_url_bb  artist_id_az artist_group_az  \
# 0  /artist/275128/b-c-d-boogie-woogie           NaN             NaN
# 1            /artist/275133/band-bees           NaN             NaN
# 2         /artist/6824928/a-lu-a-zhuo           NaN             NaN
# 3               /artist/7665908/a-niu           NaN             NaN
# 4              /artist/1481643/a-plus           NaN             NaN
#
#   artist_name_az artist_url_az
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN

# %%
az_artist_data.head()
# Out:
#    artist_id_az artist_group   artist_name         artist_url
# 0             1            A            A1          a/a1.html
# 1             2            A             A           a/a.html
# 2             3            A       Aaliyah     a/aaliyah.html
# 3             4            A  Aalto, Saara  s/saaraaalto.html
# 4             5            A      Aaradhna    a/aaradhna.html

# %%
nlp = spacy.load('en_core_web_sm')
words = []

for index, row in az_artist_data.iterrows():
    # t_artist_name_az = removeSingleCharStopWords(addSpaceAfterDot(row['artist_name']))
    t_artist_name_az = removeDuplicate(removeSingleCharStopWords(row['artist_name']))
    words.append(t_artist_name_az)

print('Created Word List!')
# Out:
# Created Word List!

# %%
word = 'America The Beautiful'
w = removeDuplicate(removeSingleCharStopWords(word))
[l, n] = intersection(w, words)
print([words[l[i]] for i in range(len(l))], n, w)
# Out:
# [['beautiful', 'south', 'the'], ['world', 'is', 'beautiful', 'place', 'am', 'no', 'longer', 'afraid', 'to', 'die', 'the']] 2 ['america', 'the', 'beautiful']

# %%
current_count = 1

for index, row in artist_data.iterrows():
    # artist_name_bb = removeSingleCharStopWords(addSpaceAfterDot(row['artist_name_bb']))
    artist_name_bb = removeDuplicate(removeSingleCharStopWords(row['artist_name_bb']))
    artist_name_az = row['artist_name_az']
    
    if pd.isna(artist_name_az):
        [match_index, match_index_lenght]  = intersection(artist_name_bb, words)
        if len(match_index) >= 1:
            print('IN:', row['artist_name_bb'], ' > ', artist_name_bb)
            print('OUT:', [words[match_index[i]] for i in range(len(match_index))])
            print(match_index_lenght/len(artist_name_bb))
            print('-------------')
    
    current_count += 1
    
    if current_count > 1000:
        break

print('Process Matching - Done!')
# Out:
# IN: A B C & D of Boogie Woogie  >  ['boogie', 'woogie']
# OUT: [['boogie'], ['boogie', 'wit', 'da', 'hoodie']]
# 0.5
# -------------
# IN: A Band of Bees  >  ['band', 'bees']
# OUT: [['alex', 'band'], ['allman', 'brothers', 'band', 'the'], ['average', 'white', 'band'], ['band', 'aid', '20'], ['band', 'aid', '30'], ['band', 'alex'], ['band', 'of', 'horses'], ['band', 'of', 'skulls'], ['band', 'perry', 'the'], ['band', 'the'], ['captain', 'beefheart', 'the', 'magic', 'band'], ['casey', 'donahew', 'band'], ['charlie', 'daniels', 'band', 'the'], ['climax', 'blues', 'band'], ['da', 'band'], ['dave', 'matthews', 'band'], ['david', 'crowder', 'band'], ['derek', 'trucks', 'band', 'the'], ['eli', 'young', 'band'], ['gap', 'band', 'the'], ['graham', 'colton', 'band'], ['greg', 'kihn', 'band'], ['james', 'barker', 'band'], ['jeff', 'healey', 'band', 'the'], ['j.', 'geils', 'band', 'the'], ['john', 'cafferty', 'the', 'beaver', 'brown', 'band'], ['john', 'fred', 'his', 'playboy', 'band'], ['josh', 'abbott', 'band'], ['kc', 'and', 'the', 'sunshine', 'band'], ['little', 'river', 'band'], ['manfred', 'mann', "'s", 'earth', 'band'], ['marshall', 'tucker', 'band', 'the'], ['matthew', 'good', 'band'], ['naked', 'brothers', 'band', 'the'], ['nitty', 'gritty', 'dirt', 'band'], ['randy', 'rogers', 'band'], ['rhett', 'walker', 'band'], ['spencer', 'lee', 'band', 'the'], ['starland', 'vocal', 'band'], ['steve', 'miller', 'band', 'the'], ['tedeschi', 'trucks', 'band'], ['zac', 'brown', 'band']]
# 0.5
# -------------
# IN: A Lu A Zhuo  >  ['lu', 'zhuo']
# OUT: [['lu']]
# 0.5
# -------------
# IN: A Plus  >  ['plus']
# OUT: [['plus', 'one']]
# 1.0
# -------------
# IN: A RUN  >  ['run']
# OUT: [['amber', 'run'], ['half', 'moon', 'run'], ['run', 'dmc'], ['run', 'the', 'jewels'], ['straylight', 'run']]
# 1.0
# -------------
# IN: A Si, Yoga Lin  >  ['si', 'yoga', 'lin']
# OUT: [['lin', 'manuel', 'miranda'], ['miranda', 'lin', 'manuel']]
# 0.3333333333333333
# -------------
# IN: A&S Project  >  ['a&s', 'project']
# OUT: [['alan', 'parsons', 'project', 'the'], ['drax', 'project'], ['fly', 'project'], ['guru', 'josh', 'project'], ['jj', 'project'], ['project', '86'], ['project', 'pat'], ['project', 'wyze']]
# 0.5
# -------------
# IN: A-Dub  >  ['dub']
# OUT: [['df', 'dub']]
# 1.0
# -------------
# IN: A-Lin  >  ['lin']
# OUT: [['lin', 'manuel', 'miranda'], ['miranda', 'lin', 'manuel']]
# 1.0
# -------------
# IN: A-Lin  >  ['lin']
# OUT: [['lin', 'manuel', 'miranda'], ['miranda', 'lin', 'manuel']]
# 1.0
# -------------
# IN: A-Lin  >  ['lin']
# OUT: [['lin', 'manuel', 'miranda'], ['miranda', 'lin', 'manuel']]
# 1.0
# -------------
# IN: A-Lin  >  ['lin']
# OUT: [['lin', 'manuel', 'miranda'], ['miranda', 'lin', 'manuel']]
# 1.0
# -------------
# IN: A-Peace  >  ['peace']
# OUT: [['atoms', 'for', 'peace'], ['disturbing', 'tha', 'peace'], ['our', 'lady', 'peace'], ['peace']]
# 1.0
# -------------
# IN: A. Beyonce  >  ['a.', 'beyonce']
# OUT: [['beyonce', 'knowles'], ['knowles', 'beyonce']]
# 0.5
# -------------
# IN: A. J. Pappas  >  ['a.', 'j.', 'pappas']
# OUT: [['j.', 'cole'], ['j.', 'dash'], ['j.', 'geils', 'band', 'the'], ['j.', 'holiday'], ['j.', 'moss'], ['j.', 'stalin'], ['j.', 'valentine']]
# 0.3333333333333333
# -------------
# IN: A. Jay Popoff  >  ['a.', 'jay', 'popoff']
# OUT: [['ayo', 'jay'], ['brannan', 'jay'], ['dawn', 'jay'], ['jay', 'ayo'], ['jay', 'brannan'], ['jay', 'critch'], ['jay', 'electronica'], ['jay', 'park'], ['jay'], ['jay', 'rock'], ['jay', 'sean'], ['jay', 'som'], ['jay', 'the', 'americans'], ['jay'], ['lil', 'jay'], ['sean', 'jay'], ['ybn', 'almighty', 'jay']]
# 0.3333333333333333
# -------------
# IN: A. Score  >  ['a.', 'score']
# OUT: [['score', 'the']]
# 0.5
# -------------
# IN: A.B. Quintanilla y los Kumbia Kings  >  ['a.b.', 'quintanilla', 'los', 'kumbia', 'kings']
# OUT: [['kumbia', 'kings']]
# 0.4
# -------------
# IN: A.B. Quintanilla's All Starz  >  ['a.b.', 'quintanilla', "'s", 'all', 'starz']
# OUT: [['abandon', 'all', 'ships'], ['all', 'one'], ['all', 'about', 'she'], ['all', 'american', 'rejects', 'the'], ['all', 'good', 'things'], ['all', 'saints'], ['all', 'sons', 'daughters'], ['all', 'star', 'tribute'], ['all', 'that', 'remains'], ['all', 'time', 'low'], ['ashley', 'all', 'day'], ['for', 'all', 'eternity'], ['for', 'all', 'seasons'], ['for', 'all', 'those', 'sleeping'], ['odd', 'future', 'wolf', 'gang', 'kill', 'them', 'all'], ['sick', 'of', 'it', 'all']]
# 0.2
# -------------
# IN: A.B.K. International  >  ['a.b.k.', 'international']
# OUT: [['international', 'five']]
# 0.5
# -------------
# IN: A.C. Newman  >  ['a.c.', 'newman']
# OUT: [['john', 'newman'], ['newman', 'john'], ['newman', 'randy'], ['randy', 'newman']]
# 0.5
# -------------
# IN: A.J. Barrett  >  ['a.j.', 'barrett']
# OUT: [['barrett', 'syd'], ['syd', 'barrett']]
# 0.5
# -------------
# IN: A.J. Brown  >  ['a.j.', 'brown']
# OUT: [['allman', 'brown'], ['andy', 'brown'], ['anthony', 'brown', 'group', 'therapy'], ['bobby', 'brown'], ['brown', 'allman'], ['brown', 'andy'], ['brown', 'boy'], ['brown', 'charlie'], ['brown', 'chris'], ['brown', 'clark', 'maurette'], ['brown', 'danny'], ['brown', 'foxy'], ['brown', 'havana'], ['brown', 'james'], ['brown', 'kaci'], ['brown', 'kane'], ['brown', 'sam'], ['buddy', 'brown'], ['charlie', 'brown'], ['charlie', 'brown', 'jr.'], ['chris', 'brown'], ['danny', 'brown'], ['foxy', 'brown'], ['havana', 'brown'], ['james', 'brown'], ['john', 'cafferty', 'the', 'beaver', 'brown', 'band'], ['kaci', 'brown'], ['kane', 'brown'], ['koffee', 'brown'], ['maurette', 'brown', 'clark'], ['sam', 'brown'], ['sawyer', 'brown'], ['sleepy', 'brown'], ['vv', 'brown'], ['zac', 'brown', 'band']]
# 0.5
# -------------
# IN: A.J. Croce  >  ['a.j.', 'croce']
# OUT: [['croce', 'jim'], ['jim', 'croce']]
# 0.5
# -------------
# IN: A.K. Webster  >  ['a.k.', 'webster']
# OUT: [['down', 'with', 'webster']]
# 0.5
# -------------
# IN: A.L.T. & the Lost Civilization  >  ['a.l.t.', 'lost', 'civilization']
# OUT: [['lost', 'boyz'], ['lost', 'frequencies'], ['lost', 'kings'], ['lost', 'trailers', 'the'], ['paradise', 'lost']]
# 0.3333333333333333
# -------------
# IN: A.P. Carter  >  ['a.p.', 'carter']
# OUT: [['aaron', 'carter'], ['carter', 'aaron'], ['carter', 'deana'], ['carter', 'grace'], ['carter', 'nick'], ['carter', 'reynolds'], ['carter', 'tyler'], ['deana', 'carter'], ['frank', 'carter', 'the', 'rattlesnakes'], ['grace', 'carter'], ['nick', 'carter'], ['reynolds', 'carter'], ['tyler', 'carter']]
# 0.5
# -------------
# IN: Aanysa x Snakehips  >  ['aanysa', 'snakehips']
# OUT: [['snakehips']]
# 0.5
# -------------
# IN: Aarif Lee  >  ['aarif', 'lee']
# OUT: [['alana', 'lee'], ['amos', 'lee'], ['amy', 'lee'], ['ben', 'lee'], ['brenda', 'lee'], ['brice', 'lee'], ['coco', 'lee'], ['david', 'lee', 'murphy'], ['david', 'lee', 'roth'], ['dewyze', 'lee'], ['fields', 'lee'], ['greenwood', 'lee'], ['harding', 'lee'], ['hi', 'lee'], ['jacob', 'lee'], ['jacquie', 'lee'], ['jerry', 'lee', 'lewis'], ['johnny', 'lee'], ['lee', 'amos'], ['lee', 'amy'], ['lee', 'ann', 'womack'], ['lee', 'ben'], ['lee', 'brenda'], ['lee', 'brice'], ['lee', 'coco'], ['lee', 'dewyze'], ['lee', 'fields'], ['lee', 'greenwood'], ['lee', 'harding'], ['lee', 'hi'], ['lee', 'jacob'], ['lee', 'jacquie'], ['lee', 'johnny'], ['lee', 'murphy'], ['lee', 'peggy'], ['lee', 'ryan'], ['lee', 'spencer'], ['lee', 'tommy'], ['lee', 'trip'], ['lewis', 'jerry', 'lee'], ['murphy', 'david', 'lee'], ['murphy', 'lee'], ['olsen', 'steven', 'lee'], ['peggy', 'lee'], ['ricki', 'lee'], ['roth', 'david', 'lee'], ['ryan', 'lee'], ['spencer', 'lee'], ['spencer', 'lee', 'band', 'the'], ['stagga', 'lee'], ['steven', 'lee', 'olsen'], ['swae', 'lee'], ['tommy', 'lee'], ['tommy', 'lee', 'sparta'], ['treal', 'lee'], ['trip', 'lee'], ['womack', 'lee', 'ann']]
# 0.5
# -------------
# IN: Aaron "Sqwid" Tosti  >  ['aaron', 'sqwid', 'tosti']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.3333333333333333
# -------------
# IN: Aaron "Zeke" Dauner  >  ['aaron', 'zeke', 'dauner']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.3333333333333333
# -------------
# IN: Aaron & Jeoffrey  >  ['aaron', 'jeoffrey']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Abraham  >  ['aaron', 'abraham']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Aedy  >  ['aaron', 'aedy']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Barrett  >  ['aaron', 'barrett']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Bedard  >  ['aaron', 'bedard']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Behrens  >  ['aaron', 'behrens']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Benward  >  ['aaron', 'benward']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Berg  >  ['aaron', 'berg']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Blanton  >  ['aaron', 'blanton']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Boyd  >  ['aaron', 'boyd']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Bruno  >  ['aaron', 'bruno']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Clark  >  ['aaron', 'clark']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Collins  >  ['aaron', 'collins']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Comess  >  ['aaron', 'comess']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Conte  >  ['aaron', 'conte']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Coyes  >  ['aaron', 'coyes']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Crabb  >  ['aaron', 'crabb']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Crawford  >  ['aaron', 'crawford']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Dalbec  >  ['aaron', 'dalbec']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Davidson  >  ['aaron', 'davidson']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Dilloway  >  ['aaron', 'dilloway']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Edge  >  ['aaron', 'edge']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Eikenberry  >  ['aaron', 'eikenberry']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Embry  >  ['aaron', 'embry']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Escolopio  >  ['aaron', 'escolopio']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Espe  >  ['aaron', 'espe']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Evers  >  ['aaron', 'evers']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Fink  >  ['aaron', 'fink']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Floyd  >  ['aaron', 'floyd']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Ford  >  ['aaron', 'ford']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Gainer  >  ['aaron', 'gainer']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Gilbert  >  ['aaron', 'gilbert']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Goldman  >  ['aaron', 'goldman']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Green  >  ['aaron', 'green']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Harris  >  ['aaron', 'harris']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Hemphill  >  ['aaron', 'hemphill']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Huffman  >  ['aaron', 'huffman']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Johnston  >  ['aaron', 'johnston']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Kamstra  >  ['aaron', 'kamstra']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Kierbel  >  ['aaron', 'kierbel']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Kwok  >  ['aaron', 'kwok']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Lippert  >  ['aaron', 'lippert']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Lord  >  ['aaron', 'lord']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Love  >  ['aaron', 'love']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Loveland  >  ['aaron', 'loveland']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Lunsford  >  ['aaron', 'lunsford']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Marsh  >  ['aaron', 'marsh']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Maxwell  >  ['aaron', 'maxwell']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Mills  >  ['aaron', 'mills']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Montgomery  >  ['aaron', 'montgomery']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Moreland  >  ['aaron', 'moreland']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Neigher  >  ['aaron', 'neigher']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Nelson  >  ['aaron', 'nelson']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Owens  >  ['aaron', 'owens']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Patrick  >  ['aaron', 'patrick']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Peltz  >  ['aaron', 'peltz']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Perrino  >  ['aaron', 'perrino']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Pfenning  >  ['aaron', 'pfenning']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Pillar  >  ['aaron', 'pillar']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Radaczyk  >  ['aaron', 'radaczyk']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Ramsey  >  ['aaron', 'ramsey']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Robinson  >  ['aaron', 'robinson']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Ross  >  ['aaron', 'ross']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Rossi  >  ['aaron', 'rossi']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Rothe  >  ['aaron', 'rothe']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Rubin  >  ['aaron', 'rubin']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Ruby  >  ['aaron', 'ruby']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Solowoniuk  >  ['aaron', 'solowoniuk']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Sperske  >  ['aaron', 'sperske']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Stern  >  ['aaron', 'stern']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Stuart  >  ['aaron', 'stuart']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Tate  >  ['aaron', 'tate']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Tollefson  >  ['aaron', 'tollefson']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Turner  >  ['aaron', 'turner']
# OUT: [['aaron', 'carpenter'], ['aaron', 'carter'], ['aaron', 'cole'], ['aaron', 'fresh'], ['aaron', 'goodvin'], ['aaron', 'lewis'], ['aaron', 'lines'], ['aaron', 'neville'], ['aaron', 'shust'], ['aaron', 'tippin'], ['aaron', 'watson'], ['carpenter', 'aaron'], ['carter', 'aaron'], ['cole', 'aaron'], ['fresh', 'aaron'], ['goodvin', 'aaron'], ['lewis', 'aaron'], ['lines', 'aaron'], ['neville', 'aaron'], ['shust', 'aaron'], ['tippin', 'aaron'], ['watson', 'aaron']]
# 0.5
# -------------
# IN: Aaron Vásquez  >  ['aaron', 'vásquez']
# ...
# IN: Alpha Cat  >  ['alpha', 'cat']
# OUT: [['alpha', 'rev']]
# 0.5
# -------------
# IN: Alphonso Martin  >  ['alphonso', 'martin']
# OUT: [['chris', 'martin'], ['dean', 'martin'], ['garrix', 'martin'], ['jensen', 'martin'], ['john', 'martin'], ['keith', 'martin'], ['martin', 'chris'], ['martin', 'dean'], ['martin', 'garrix'], ['martin', 'jensen'], ['martin', 'john'], ['martin', 'keith'], ['martin', 'nievera'], ['martin', 'ricky'], ['martin', 'solveig'], ['martin', 'terrace'], ['martin', 'tungevaag'], ['nievera', 'martin'], ['ricky', 'martin'], ['shy', 'martin'], ['solveig', 'martin'], ['terrace', 'martin'], ['tungevaag', 'martin']]
# 0.5
# -------------
# IN: Alquimia la Sonora del XXI Leyenda  >  ['alquimia', 'la', 'sonora', 'del', 'xxi', 'leyenda']
# OUT: [['amara', 'la', 'negra'], ['de', 'la', 'ghetto'], ['de', 'la', 'rocha', 'zack'], ['de', 'la', 'soul'], ['kyla', 'la', 'grange'], ['la', 'dispute'], ['la', 'fouine'], ['la', 'grange', 'kyla'], ['la', 'land', 'cast'], ['la', 'oreja', 'de', 'van', 'gogh'], ['la', 'rose', 'natalie'], ['la', 'roux'], ['la', 'squale', 'moha'], ['la', "'s", 'the'], ['lianne', 'la', 'havas'], ['moha', 'la', 'squale'], ['natalie', 'la', 'rose'], ['yo', 'la', 'tengo'], ['zack', 'de', 'la', 'rocha']]
# 0.16666666666666666
# -------------
# IN: Altar Boys  >  ['altar', 'boys']
# OUT: [['backstreet', 'boys'], ['beach', 'boys'], ['beastie', 'boys'], ['boys', 'like', 'girls'], ['boys', 'of', 'fall'], ['tent', 'boys'], ['geto', 'boys'], ['hot', 'boys'], ['junior', 'boys'], ['los', 'lonely', 'boys'], ['lucky', 'boys', 'confusion'], ['oak', 'ridge', 'boys', 'the'], ['ordinary', 'boys', 'the'], ['pet', 'shop', 'boys']]
# 0.5
# -------------
# IN: Althea Smith  >  ['althea', 'smith']
# OUT: [['april', 'smith'], ['april', 'smith', 'and', 'the', 'great', 'picture', 'show'], ['caitlyn', 'smith'], ['canaan', 'smith'], ['corey', 'smith'], ['dallas', 'smith'], ['elliott', 'smith'], ['granger', 'smith'], ['jaden', 'smith'], ['jordan', 'smith'], ['jorja', 'smith'], ['kim', 'walker', 'smith'], ['michael', 'w.', 'smith'], ['mindy', 'smith'], ['patti', 'smith'], ['sam', 'smith'], ['smith', 'april'], ['smith', 'caitlyn'], ['smith', 'canaan'], ['smith', 'corey'], ['smith', 'dallas'], ['smith', 'elliott'], ['smith', 'granger'], ['smith', 'jaden'], ['smith', 'jordan'], ['smith', 'jorja'], ['smith', 'michael', 'w.'], ['smith', 'mindy'], ['smith', 'patti'], ['smith', 'westerns'], ['smith', 'will'], ['smith', 'willow'], ['walker', 'smith', 'kim'], ['willow', 'smith'], ['will', 'smith']]
# 0.5
# -------------
# IN: Alto Reed  >  ['alto', 'reed']
# OUT: [['deming', 'reed'], ['jerry', 'reed'], ['lou', 'reed'], ['reed', 'deming'], ['reed', 'jerry'], ['reed', 'lou']]
# 0.5
# -------------
# IN: Alton McClain  >  ['alton', 'mcclain']
# OUT: [['china', 'anne', 'mcclain'], ['mcclain', 'china', 'anne'], ['mcclain', 'sisters']]
# 0.5
# -------------
# IN: Alvaro Diez  >  ['alvaro', 'diez']
# OUT: [['alvaro', 'soler'], ['soler', 'alvaro']]
# 0.5
# -------------
# IN: Alvaro Pava  >  ['alvaro', 'pava']
# OUT: [['alvaro', 'soler'], ['soler', 'alvaro']]
# 0.5
# -------------
# IN: Alvin  >  ['alvin']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 1.0
# -------------
# IN: Alvin  >  ['alvin']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 1.0
# -------------
# IN: Alvin & the Chipmunks  >  ['alvin', 'chipmunks']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 1.0
# -------------
# IN: Alvin Cash & the Crawlers  >  ['alvin', 'cash', 'crawlers']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.3333333333333333
# -------------
# IN: Alvin Cash & The Registers  >  ['alvin', 'cash', 'the', 'registers']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.5
# -------------
# IN: Alvin Chea  >  ['alvin', 'chea']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.5
# -------------
# IN: Alvin Ewen  >  ['alvin', 'ewen']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.5
# -------------
# IN: Alvin Patterson  >  ['alvin', 'patterson']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.5
# -------------
# IN: Alvin Pazant  >  ['alvin', 'pazant']
# OUT: [['alvin', 'and', 'the', 'chipmunks']]
# 0.5
# -------------
# IN: Alvino Bennett  >  ['alvino', 'bennett']
# OUT: [['bennett', 'taylor'], ['bennett', 'tony'], ['taylor', 'bennett'], ['tony', 'bennett']]
# 0.5
# -------------
# IN: Aly  >  ['aly']
# OUT: [['aly', 'aj']]
# 1.0
# -------------
# IN: Aly Bain  >  ['aly', 'bain']
# OUT: [['aly', 'aj']]
# 0.5
# -------------
# IN: Alyrio Lima  >  ['alyrio', 'lima']
# OUT: [['gusttavo', 'lima'], ['lima', 'gusttavo']]
# 0.5
# -------------
# IN: Alyson Calagna  >  ['alyson', 'calagna']
# OUT: [['alyson', 'stoner'], ['stoner', 'alyson']]
# 0.5
# -------------
# IN: Alyssa Barlow  >  ['alyssa', 'barlow']
# OUT: [['alyssa', 'reid'], ['reid', 'alyssa']]
# 0.5
# -------------
# IN: Alyssa Ruschak  >  ['alyssa', 'ruschak']
# OUT: [['alyssa', 'reid'], ['reid', 'alyssa']]
# 0.5
# -------------
# IN: Am Kidd  >  ['am', 'kidd']
# OUT: [['am', 'king'], ['am', 'they'], ['world', 'is', 'beautiful', 'place', 'am', 'no', 'longer', 'afraid', 'to', 'die', 'the']]
# 0.5
# -------------
# IN: AM/FM  >  ['am', 'fm']
# OUT: [['fm', 'static']]
# 0.5
# -------------
# IN: Amadee Castenell, Jr.  >  ['amadee', 'castenell', 'jr.']
# OUT: [['albert', 'hammond', 'jr.'], ['charlie', 'brown', 'jr.'], ['clark', 'jr.', 'gary'], ['connick', 'jr.', 'harry'], ['dinosaur', 'jr.'], ['gary', 'clark', 'jr.'], ['george', 'tandy', 'jr.'], ['hammond', 'jr.', 'albert'], ['hank', 'williams', 'jr.'], ['harry', 'connick', 'jr.'], ['jones', 'jr.', 'roy'], ['parker', 'jr.', 'ray'], ['ray', 'parker', 'jr.'], ['roy', 'jones', 'jr.'], ['wheeler', 'walker', 'jr.'], ['williams', 'jr.', 'hank']]
# 0.3333333333333333
# -------------
# IN: Amado Jr. Garza  >  ['amado', 'jr.', 'garza']
# OUT: [['albert', 'hammond', 'jr.'], ['charlie', 'brown', 'jr.'], ['clark', 'jr.', 'gary'], ['connick', 'jr.', 'harry'], ['dinosaur', 'jr.'], ['gary', 'clark', 'jr.'], ['george', 'tandy', 'jr.'], ['hammond', 'jr.', 'albert'], ['hank', 'williams', 'jr.'], ['harry', 'connick', 'jr.'], ['jones', 'jr.', 'roy'], ['parker', 'jr.', 'ray'], ['ray', 'parker', 'jr.'], ['roy', 'jones', 'jr.'], ['wheeler', 'walker', 'jr.'], ['williams', 'jr.', 'hank']]
# 0.3333333333333333
# -------------
# IN: Amador Alvarado  >  ['amador', 'alvarado']
# OUT: [['amador', 'ryan'], ['ryan', 'amador']]
# 0.5
# -------------
# IN: Amanda Blue  >  ['amanda', 'blue']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Cole  >  ['amanda', 'cole']
# OUT: [['aaron', 'cole'], ['cheryl', 'cole'], ['cole', 'aaron'], ['cole', 'keyshia'], ['cole', 'kimberly'], ['cole', 'natalie'], ['cole', 'nat', 'king'], ['cole', 'paula'], ['cole', 'swindell'], ['j.', 'cole'], ['keyshia', 'cole'], ['kimberly', 'cole'], ['natalie', 'cole'], ['nat', 'king', 'cole'], ['paula', 'cole'], ['swindell', 'cole']]
# 0.5
# -------------
# IN: Amanda Diva  >  ['amanda', 'diva']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Glanfield  >  ['amanda', 'glanfield']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Kramer  >  ['amanda', 'kramer']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Scheer-Demme  >  ['amanda', 'scheer', 'demme']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.3333333333333333
# -------------
# IN: Amanda Tannen  >  ['amanda', 'tannen']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Vincent  >  ['amanda', 'vincent']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amanda Watkins  >  ['amanda', 'watkins']
# OUT: [['amanda'], ['amanda', 'black'], ['amanda', 'cook'], ['amanda', 'delara'], ['amanda', 'marshall'], ['amanda', 'palmer'], ['amanda', 'perez'], ['amanda', 'seyfried'], ['amanda', 'somerville'], ['amanda', 'stott'], ['black', 'amanda'], ['cook', 'amanda'], ['delara', 'amanda'], ['marshall', 'amanda'], ['palmer', 'amanda'], ['perez', 'amanda'], ['seyfried', 'amanda'], ['somerville', 'amanda'], ['stott', 'amanda']]
# 0.5
# -------------
# IN: Amandah Wilkinson  >  ['amandah', 'wilkinson']
# OUT: [['wilkinson']]
# 0.5
# -------------
# IN: Amar Khalil  >  ['amar', 'khalil']
# OUT: [['khalil']]
# 0.5
# -------------
# IN: Amarante  >  ['amarante']
# OUT: [['amarante', 'rodrigo'], ['rodrigo', 'amarante']]
# 1.0
# -------------
# IN: Amazing Grace  >  ['amazing', 'grace']
# OUT: [['bridge', 'to', 'grace'], ['carter', 'grace'], ['goody', 'grace'], ['grace'], ['grace', 'carter'], ['grace', 'jamie'], ['grace', 'jones'], ['grace', 'leslie'], ['grace', 'phipps'], ['grace', 'potter'], ['grace', 'potter', 'and', 'the', 'nocturnals'], ['grace', 'sophia'], ['grace', 'vanderwaal'], ['jamie', 'grace'], ['jones', 'grace'], ['leslie', 'grace'], ['moments', 'in', 'grace'], ['phipps', 'grace'], ['point', 'of', 'grace'], ['sophia', 'grace'], ['three', 'days', 'grace'], ['times', 'of', 'grace'], ['vanderwaal', 'grace']]
# 0.5
# -------------
# IN: The Amazing Rhythm Aces  >  ['the', 'amazing', 'rhythm', 'aces']
# OUT: [['aces', 'the']]
# 0.5
# -------------
# IN: Amber An, Show Lo  >  ['amber', 'an', 'show', 'lo']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.25
# -------------
# IN: Amber Kuo  >  ['amber', 'kuo']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.5
# -------------
# IN: Amber Kuo  >  ['amber', 'kuo']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.5
# -------------
# IN: Amber Kuo  >  ['amber', 'kuo']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.5
# -------------
# IN: Amber Kuo & Cai Guoqing   >  ['amber', 'kuo', 'cai', 'guoqing']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.25
# -------------
# IN: Amber Ross  >  ['amber', 'ross']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.5
# -------------
# IN: Amber Webber  >  ['amber', 'webber']
# OUT: [['amber', 'mark'], ['amber', 'pacific'], ['amber', 'riley'], ['amber', 'rose'], ['amber', 'run'], ['mark', 'amber'], ['riley', 'amber'], ['rose', 'amber']]
# 0.5
# -------------
# IN: Amedeo Pace  >  ['amedeo', 'pace']
# OUT: [['change', 'of', 'pace']]
# 0.5
# -------------
# IN: Amee Joy Williamson  >  ['amee', 'joy', 'williamson']
# OUT: [['bethany', 'joy', 'lenz'], ['jesse', 'joy'], ['joy'], ['joy', 'division'], ['joy', 'formidable', 'the'], ['joy', 'williams'], ['lenz', 'bethany', 'joy'], ['vance', 'joy'], ['williams', 'joy']]
# 0.3333333333333333
# -------------
# IN: America The Beautiful  >  ['america', 'the', 'beautiful']
# OUT: [['beautiful', 'south', 'the'], ['world', 'is', 'beautiful', 'place', 'am', 'no', 'longer', 'afraid', 'to', 'die', 'the']]
# 0.6666666666666666
# -------------
# IN: American Idol Finalists  >  ['american', 'idol', 'finalists']
# OUT: [['all', 'american', 'rejects', 'the'], ['american', 'authors'], ['american', 'football'], ['american', 'head', 'charge'], ['american', 'hi', 'fi'], ['american', 'juniors'], ['american', 'nightmare']]
# 0.3333333333333333
# -------------
# IN: American Tenors  >  ['american', 'tenors']
# OUT: [['all', 'american', 'rejects', 'the'], ['american', 'authors'], ['american', 'football'], ['american', 'head', 'charge'], ['american', 'hi', 'fi'], ['american', 'juniors'], ['american', 'nightmare']]
# 0.5
# -------------
# IN: Amery AWOL Smith  >  ['amery', 'awol', 'smith']
# OUT: [['april', 'smith'], ['april', 'smith', 'and', 'the', 'great', 'picture', 'show'], ['caitlyn', 'smith'], ['canaan', 'smith'], ['corey', 'smith'], ['dallas', 'smith'], ['elliott', 'smith'], ['granger', 'smith'], ['jaden', 'smith'], ['jordan', 'smith'], ['jorja', 'smith'], ['kim', 'walker', 'smith'], ['michael', 'w.', 'smith'], ['mindy', 'smith'], ['patti', 'smith'], ['sam', 'smith'], ['smith', 'april'], ['smith', 'caitlyn'], ['smith', 'canaan'], ['smith', 'corey'], ['smith', 'dallas'], ['smith', 'elliott'], ['smith', 'granger'], ['smith', 'jaden'], ['smith', 'jordan'], ['smith', 'jorja'], ['smith', 'michael', 'w.'], ['smith', 'mindy'], ['smith', 'patti'], ['smith', 'westerns'], ['smith', 'will'], ['smith', 'willow'], ['walker', 'smith', 'kim'], ['willow', 'smith'], ['will', 'smith']]
# 0.3333333333333333
# -------------
# IN: Amir Derakh  >  ['amir', 'derakh']
# OUT: [['amir']]
# 0.5
# -------------
# IN: Amit Paul  >  ['amit', 'paul']
# OUT: [['anka', 'paul'], ['baloche', 'paul'], ['billy', 'paul'], ['brandt', 'paul'], ['carrack', 'paul'], ['jake', 'paul'], ['kelly', 'paul'], ['logan', 'paul'], ['mccartney', 'paul'], ['mcdonald', 'paul'], ['oakenfold', 'paul'], ['paul', 'anka'], ['paul', 'baloche'], ['paul', 'billy'], ['paul', 'brandt'], ['paul', 'carrack'], ['paul', 'heaton', 'jacqui', 'abbott'], ['paul', 'jake'], ['paul', 'kelly'], ['paul', 'logan'], ['paul', 'mccartney'], ['paul', 'mcdonald'], ['paul', 'oakenfold'], ['paul', 'revere', 'the', 'raiders'], ['paul', 'sean'], ['paul', 'simon'], ['paul', 'van', 'dyk'], ['paul', 'wall'], ['paul', 'weller'], ['paul', 'young'], ['peter', 'paul', 'and', 'mary'], ['sean', 'paul'], ['simon', 'paul'], ['van', 'dyk', 'paul'], ['weller', 'paul'], ['young', 'paul']]
# 0.5
# -------------
# Process Matching - Done!

# %%
fz = fuzzyset.FuzzySet()
fz_data = az_artist_data['artist_name'].values
for l in fz_data:
    fz.add(l)

# %%
current_count = 1

for index, row in artist_data.iterrows():
    artist_name_bb = row['artist_name_bb']
    artist_name_az = row['artist_name_az']
    
    if pd.isna(artist_name_az):
        print('IN:', artist_name_bb)
        print('OUT:', fz.get(artist_name_bb))
        print('-------------')
    
    current_count += 1
    
    if current_count > 100:
        break

print('Process Matching - Done!')

# %%
artist_match_accuracy = []
artist_match_count = []
artist_index_set = []

current_count = 1
total_count = len(artist_data.index)

print('Started Processing: ', total_count, 'Records')

for index, row in artist_data.iterrows():
    artist_group_az = ''
    artist_name_az = ''
    artist_url_az = 0
    
    artist_name_bb = row['artist_name_bb']
    artist_name_az = row['artist_name_az']
    
    if pd.isna(artist_name_bb):
        artist_match_accuracy.append(0.00)
        artist_index_set.append('Null/Nan - Ignored')
        artist_match_count.append(0)
    else:
        if pd.isna(artist_name_az):
            [artist_group_az, artist_name_az, artist_url_az, accuracy, index_set, match_count]\
                = getArtistDetailsFromAZ(artist_name_bb)
            artist_data.at[index, 'artist_group_az'] = artist_group_az
            artist_data.at[index, 'artist_name_az'] = artist_name_az
            artist_data.at[index, 'artist_url_az'] = artist_url_az
            artist_match_accuracy.append(accuracy)
            artist_index_set.append(index_set)
            artist_match_count.append(match_count)
        else:
            artist_match_accuracy.append(2.00)
            artist_index_set.append('Direct Relational Match')
            artist_match_count.append(0)
    
    if (current_count % 100) == 0:
        print('Processed: ', current_count, ' / ', total_count)
    
    current_count += 1
    
    if current_count > 10:
        break
        
artist_data['artist_match_accuracy_az'] = artist_match_accuracy
artist_data['artist_index_set_az'] = artist_index_set
artist_data['artist_match_count_az'] = artist_match_count

print('Process Matching - Done!')

# %%
setlist = [{'Chloe', 'Adams,'}, {'Joel', 'Adams,'}, {'Adams,', 'Oleta'}, {'Peter', 'Bradley', 'Adams,'}]
set.intersection(*setlist)
# Out:
# {'Adams,'}
